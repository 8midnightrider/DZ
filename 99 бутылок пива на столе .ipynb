# %% [markdown]
# # Делать компактнее лень
# ## Что первое в голову пришло, то и написал
# ## Не ломаю то, что работает))

# %%
import num2words as n2 

for i in reversed(range(1,100)):
    if i >= 21:
        if 'один' in n2.num2words(i, lang='ru'):
            b = n2.num2words(i, lang='ru').split()
            b[1] = 'одна'
            a = ' '.join(b)
            print(a, 'бутылка пива на стене\n',
                  a, 'бутылка пива!\n',
                  'Возьми одну, пусти по кругу\n',
                  n2.num2words(i-1, lang='ru'), 'бутылок пива на стене!')
        elif 'два' in n2.num2words(i, lang='ru'):
            b = n2.num2words(i, lang='ru').split()
            b[1] = 'две'
            a = ' '.join(b)
            b1 = n2.num2words(i-1, lang='ru').split()
            b1[1] = 'одна'
            a1 = ' '.join(b1)
            print(a, 'бутылки пива на стене\n',
                  a, 'бутылки пива!\n',
                  'Возьми одну, пусти по кругу\n',
                  a1, 'бутылка пива на стене!')
        elif 'три' in n2.num2words(i, lang='ru'):
            b1 = n2.num2words(i-1, lang='ru').split()
            b1[1] = 'две'
            a1 = ' '.join(b1)
            print(n2.num2words(i, lang='ru'), 'бутылки пива на стене\n',
                  n2.num2words(i, lang='ru'), 'бутылки пива!\n',
                  'Возьми одну, пусти по кругу\n',
                  a1, 'бутылки пива на стене!')
        elif 'четыре' in n2.num2words(i, lang='ru'):
            print(n2.num2words(i, lang='ru'), 'бутылки пива на стене\n',
                  n2.num2words(i, lang='ru'), 'бутылки пива!\n',
                  'Возьми одну, пусти по кругу\n',
                  n2.num2words(i-1, lang='ru'), 'бутылки пива на стене!')
        elif 'пять' in n2.num2words(i, lang='ru'):
            print(n2.num2words(i, lang='ru'), 'бутылок пива на стене\n',
                  n2.num2words(i, lang='ru'), 'бутылок пива!\n',
                  'Возьми одну, пусти по кругу\n',
                  n2.num2words(i-1, lang='ru'), 'бутылки пива на стене!')
        else:
            print(n2.num2words(i, lang='ru'), 'бутылок пива на стене\n',
                  n2.num2words(i, lang='ru'), 'бутылок пива!\n',
                  'Возьми одну, пусти по кругу\n',
                  n2.num2words(i-1, lang='ru'), 'бутылок пива на стене!')
    if i >= 6 and i <= 20:
        print(n2.num2words(i, lang='ru'), 'бутылок пива на стене\n',
              n2.num2words(i, lang='ru'), 'бутылок пива!\n',
              'Возьми одну, пусти по кругу\n',
              n2.num2words(i-1, lang='ru'), 'бутылок пива на стене!')
    if i >= 2 and i < 6:
        if 'пять' == n2.num2words(i, lang='ru'):
            print(n2.num2words(i, lang='ru'), 'бутылок пива на стене\n',
              n2.num2words(i, lang='ru'), 'бутылок пива!\n',
              'Возьми одну, пусти по кругу\n',
              n2.num2words(i-1, lang='ru'), 'бутылки пива на стене!')
        elif 'четыре' == n2.num2words(i, lang='ru'):
            print(n2.num2words(i, lang='ru'), 'бутылки пива на стене\n',
              n2.num2words(i, lang='ru'), 'бутылки пива!\n',
              'Возьми одну, пусти по кругу\n',
              n2.num2words(i-1, lang='ru'), 'бутылки пива на стене!')
        elif 'три' == n2.num2words(i, lang='ru'):
            print(n2.num2words(i, lang='ru'), 'бутылки пива на стене\n',
              n2.num2words(i, lang='ru'), 'бутылки пива!\n',
              'Возьми одну, пусти по кругу\n',
              'две', 'бутылки пива на стене!')
        elif 'два' == n2.num2words(i, lang='ru'):
            print('две', 'бутылки пива на стене\n',
              'две', 'бутылки пива!\n',
              'Возьми одну, пусти по кругу\n',
              'одна', 'бутылка пива на стене!')
    if i == 1:
        print('одна', 'бутылок пива на стене\n',
              'одна', 'бутылок пива!\n',
              'Возьми одну, пусти по кругу\n',
              'нет больше пива на стене - не беда!\n',
              'пойди в магазин и купи еще!')
